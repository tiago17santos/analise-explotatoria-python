# %% [markdown]
# # <font color='blue'>Data Science Academy</font>
#
# ## <font color='blue'>Fundamentos de Linguagem Python Para Análise de Dados e Data Science</font>
#
# ## <font color='blue'>Projeto 2</font>
#
# ## <font color='blue'>Análise Exploratória de Dados em Linguagem Python Para a Área de Varejo</font>

# %% [markdown]
# ![DSA](imagens/projeto2.png)

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.9.13

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %% [markdown]
# ## Carregando os Dados

# %%
# Carrega o dataset
df_dsa = pd.read_csv('dados/dataset.csv')

# %%
# Shape
df_dsa.shape
# Out:
# (9700, 11)

# %%
# Amostra dos dados
df_dsa.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# ...

# %%
# Amostra dos dados
df_dsa.tail()
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 9695  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9696  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9697  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9698  CA-2017-105291  30/10/2017   SP-20920     Consumer  United States
# 9699  CA-2018-147032  31/07/2018   LB-16795  Home Office  United States
#
#                Cidade      Estado       ID_Produto        Categoria  \
# 9695        Inglewood  California  OFF-PA-10004569  Office Supplies
# 9696        Inglewood  California  OFF-AP-10000027  Office Supplies
# 9697        Inglewood  California  TEC-PH-10000675       Technology
# 9698  San Luis Obispo  California  OFF-FA-10003059  Office Supplies
# 9699       Wilmington    Delaware  OFF-PA-10003256  Office Supplies
#
#      SubCategoria  Valor_Venda
# 9695        Paper       22.830
# 9696   Appliances       54.320
# ...

# %% [markdown]
# ## Análise Exploratória

# %%
# Colunas do conjunto de dados
df_dsa.columns
# Out:
# Index(['ID_Pedido', 'Data_Pedido', 'ID_Cliente', 'Segmento', 'Pais', 'Cidade',
#        'Estado', 'ID_Produto', 'Categoria', 'SubCategoria', 'Valor_Venda'],
#       dtype='object')

# %%
# Verificando o tipo de dado de cada coluna
df_dsa.dtypes
# Out:
# ID_Pedido        object
# Data_Pedido      object
# ID_Cliente       object
# Segmento         object
# Pais             object
# Cidade           object
# Estado           object
# ID_Produto       object
# Categoria        object
# SubCategoria     object
# Valor_Venda     float64
# dtype: object

# %%
# Resumo estatístico da coluna com o valor de venda
df_dsa['Valor_Venda'].describe()
# Out:
# count     9700.000000
# mean       230.469892
# std        627.504252
# min          0.444000
# 25%         17.248000
# 50%         54.272000
# 75%        209.932500
# max      22638.480000
# Name: Valor_Venda, dtype: float64

# %%
# Verificando se há registros duplicados
df_dsa[df_dsa.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID_Pedido, Data_Pedido, ID_Cliente, Segmento, Pais, Cidade, Estado, ID_Produto, Categoria, SubCategoria, Valor_Venda]
# Index: []

# %%
# Verificando de há valores ausentes
df_dsa.isnull().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Cidade          0
# Estado          0
# ID_Produto      0
# Categoria       0
# SubCategoria    0
# Valor_Venda     0
# dtype: int64

# %%
df_dsa.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# ...

# %% [markdown]
# ## Pergunta de Negócio 1:
#
# ### Qual Cidade com Maior Valor de Venda de Produtos da Categoria 'Office Supplies'?

# %%
categoria = df_dsa[df_dsa['Categoria'] == 'Office Supplies']

df_cidade = categoria.groupby('Cidade')['Valor_Venda'].sum()

df_cidade.idxmax()
# Out:
# 'New York City'

# %% [markdown]
# ## Pergunta de Negócio 2:
#
# ### Qual o Total de Vendas Por Data do Pedido?
#
# Demonstre o resultado através de um gráfico de barras.

# %%
df_date = df_dsa.groupby('Data_Pedido')['Valor_Venda'].sum()
df_date.head()
# Out:
# Data_Pedido
# 01/01/2018    1481.8280
# 01/02/2015     468.9000
# 01/02/2017     161.9700
# 01/03/2015    2203.1510
# 01/03/2016    1642.1744
# Name: Valor_Venda, dtype: float64

# %%
plt.figure(figsize = (20,6))
df_date.plot(x='Data_Pedido', y='Valor_Venda', color='green')
plt.title('Total de vendas por data do pedido')
plt.show()

# %% [markdown]
# ## Pergunta de Negócio 3:
#
# ### Qual o Total de Vendas por Estado?
#
# Demonstre o resultado através de um gráfico de barras.

# %%
df_VenEst = df_dsa.groupby('Estado')['Valor_Venda'].sum().reset_index()

plt.figure(figsize = (16,6))

sns.barplot(data = df_VenEst,
            x = 'Estado',
            y = 'Valor_Venda',).set(title =' Venda por estado')
plt.xticks(rotation = 80)
plt.show()

# %% [markdown]
# ## Pergunta de Negócio 4:
#
# ### Quais São as 10 Cidades com Maior Total de Vendas?
#
# Demonstre o resultado através de um gráfico de barras.

# %%
df_cities = df_dsa.groupby('Cidade')['Valor_Venda'].sum().reset_index().sort_values(by = 'Valor_Venda', ascending=False).head(10)

df_cities.head(10)
# Out:
#             Cidade  Valor_Venda
# 327  New York City  251749.2190
# 265    Los Angeles  171654.6330
# 450        Seattle  114725.4780
# 436  San Francisco  107489.9520
# 372   Philadelphia  107197.8030
# 207        Houston   61590.1868
# 435      San Diego   47458.3790
# 80         Chicago   46974.3430
# 216   Jacksonville   44713.1830
# 123        Detroit   42446.9440

# %%
plt.figure(figsize = (16, 6))
sns.set_palette('coolwarm')
sns.barplot(data = df_cities, 
            y = 'Valor_Venda', 
            x = 'Cidade').set(title = 'As 10 Cidades com Maior Total de Vendas')
plt.show()

# %% [markdown]
# ## Pergunta de Negócio 5:
#
# ### Qual Segmento Teve o Maior Total de Vendas?
#
# Demonstre o resultado através de um gráfico de pizza.

# %%
df_segmento = df_dsa.groupby('Segmento')['Valor_Venda'].sum().reset_index().sort_values(by = 'Valor_Venda', ascending=False)
#inserir legenda

# %%
def auto_pct_format(values):
    def my_format(pct):
        total = sum(values)
        valor = int(round(pct * total / 100))
        return '${v:d}'.format( v = valor)
    return my_format

# %%
plt.figure(figsize = (16,6))

plt.pie(df_segmento['Valor_Venda'],
       labels = df_segmento['Segmento'],
       autopct = auto_pct_format(df_segmento['Valor_Venda']),
       startangle = 90)


centre_circle = plt.Circle((0,0), 0.82, fc ='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.annotate(text = 'Total de Vendas: $' + str(int(sum(df_segmento['Valor_Venda']))), xy = (1.25,0.1))
plt.title('Número de vendas por Segmento')

plt.show()

# %% [markdown]
# ## Pergunta de Negócio 6 (Desafio Nível Baby):
#
# ### Qual o Total de Vendas Por Segmento e Por Ano?

# %%
#df_dsa['Ano'] = df_dsa['ID_Pedido'].str.split('-').str[1]

#df_dsa.groupby(['Ano','Segmento'])['Valor_Venda'].sum()

# %%
df_dsa['Data_Pedido'] = pd.to_datetime(df_dsa['Data_Pedido'], dayfirst = True)

df_dsa['Ano'] = df_dsa['Data_Pedido'].dt.year

df_dsa.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda   Ano
# 0     261.9600  2017
# 1     731.9400  2017
# 2      14.6200  2017
# ...

# %%
df_dsa_segAno = df_dsa.groupby(['Ano', 'Segmento'])['Valor_Venda'].sum()

df_dsa_segAno
# Out:
# Ano   Segmento
# 2015  Consumer       256719.9166
#       Corporate      125819.5957
#       Home Office     88229.0878
# 2016  Consumer       265295.2593
#       Corporate      114643.1229
#       Home Office     74134.1332
# 2017  Consumer       288459.5572
#       Corporate      203266.7398
#       Home Office    103639.6270
# 2018  Consumer       323359.6019
#       Corporate      235502.7284
#       Home Office    156488.5849
# Name: Valor_Venda, dtype: float64

# %% [markdown]
# ## Pergunta de Negócio 7 (Desafio Nível Júnior):
#
# Os gestores da empresa estão considerando conceder diferentes faixas de descontos e gostariam de fazer uma simulação com base na regra abaixo:
#
# - Se o Valor_Venda for maior que 1000 recebe 15% de desconto.
# - Se o Valor_Venda for menor que 1000 recebe 10% de desconto.
#
# ### Quantas Vendas Receberiam 15% de Desconto?

# %%
#df_dsa[df_dsa['Valor_Venda']> 1000.000]['Valor_Venda'].count()


df_dsa['Desconto'] = np.where(df_dsa['Valor_Venda'] > 1000, 0.15, 0.10)

df_dsa.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda   Ano  Desconto
# 0     261.9600  2017       0.1
# ...

# %%
df_dsa[df_dsa['Desconto'] == 0.15]['Desconto'].value_counts()

print('No Total 457 Vendas Receberiam Desconto de 15%.')
# Out:
# No Total 457 Vendas Receberiam Desconto de 15%.

# %% [markdown]
# ## Pergunta de Negócio 8 (Desafio Nível Master):
#
# ### Considere Que a Empresa Decida Conceder o Desconto de 15% do Item Anterior. Qual Seria a Média do Valor de Venda Antes e Depois do Desconto?

# %%
df_dsa['Valor_Venda_Desconto'] = df_dsa['Valor_Venda'] - (df_dsa['Valor_Venda'] * df_dsa['Desconto'])


#df_dsa = df_dsa.drop('Valor_Final', axis = 1)

df_dsa.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda   Ano  Desconto  Valor_Venda_Desconto
# ...

# %%
media_vendas_antes_desconto = df_dsa.loc[df_dsa['Desconto'] == 0.15, 'Valor_Venda']
# Out:
# 2116.8078153172864

# %%
media_vendas_depois_desconto = df_dsa.loc[df_dsa['Desconto'] == 0.15, 'Valor_Venda_Desconto']
# Out:
# 1799.2866430196952

# %%
print("Média das vendas antes do desconto de 15%:", round(media_vendas_antes_desconto.mean(), 2))
# Out:
# Média das vendas antes do desconto de 15%: 2116.81

# %%
print("Média das vendas depois do desconto de 15%:", round(media_vendas_depois_desconto.mean(), 2))
# Out:
# Média das vendas depois do desconto de 15%: 1799.29

# %% [markdown]
# ## Pergunta de Negócio 9 (Desafio Nível Master Ninja):
#
# ### Qual o Média de Vendas Por Segmento, Por Ano e Por Mês?
#
# Demonstre o resultado através de gráfico de linha.

# %%
#df_dsa['Mes'] = df_dsa['Data_Pedido'].str.split('/').str[1]

df_dsa['Mes'] = df_dsa['Data_Pedido'].dt.month

df_seg_ano = df_dsa.groupby(['Segmento','Ano','Mes'])['Valor_Venda'].agg([np.sum, np.mean, np.std])

df_seg_ano
# Out:
#                             sum        mean          std
# Segmento    Ano  Mes
# Consumer    2015 1     6896.629  146.736787   267.921077
#                  2     3167.854  117.327926   253.209003
#                  3    11869.304  152.170564   247.961996
#                  4     9108.612  189.762750   321.670107
#                  5    12628.271  191.337439   339.286758
# ...                         ...         ...          ...
# Home Office 2018 8     5813.300  176.160606   262.401655
#                  9    19183.826  249.140597   439.438045
#                  10   29705.515  412.576597  1389.816118
#                  11   24009.384  247.519423   451.154725
#                  12   13022.391  224.523983   449.775420
#
# [144 rows x 3 columns]

# %%
segmento = df_seg_ano.index.get_level_values(0)
ano = df_seg_ano.index.get_level_values(1)
mes = df_seg_ano.index.get_level_values(2)


sns.set()

sns.relplot(kind = 'line',
            data = df_seg_ano,
           x = mes,
           y = 'mean',
           hue = segmento,
           col = ano,
           col_wrap = 4)


plt.show()

# %% [markdown]
# ## Pergunta de Negócio 10 (Desafio Nível Master Ninja das Galáxias):
#
# ### Qual o Total de Vendas Por Categoria e SubCategoria, Considerando Somente as Top 12 SubCategorias?
#
# Demonstre tudo através de um único gráfico.

# %% [markdown]
# # Fim
